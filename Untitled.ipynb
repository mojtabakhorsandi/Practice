# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('heartp.xlsx')
df
# Out:
#      Unnamed: 0  age  sex  cp   bp  chol  fbs  elc   hr  exercise  dep  slop  \
# 0             0   63    1   1  145   233    1    2  150         0  2.3     0
# 1             1   67    1   2  160   286    0    2  108         1  1.5     2
# 2             2   67    1   2  120   229    0    2  129         1  2.6     2
# 3             3   37    1   3  130   250    0    1  187         0  3.5     0
# 4             4   41    0   0  130   204    0    2  172         0  1.4     1
# ..          ...  ...  ...  ..  ...   ...  ...  ...  ...       ...  ...   ...
# 298         298   45    1   1  110   264    0    1  132         0  1.2     2
# 299         299   68    1   2  144   193    1    1  141         0  3.4     2
# 300         300   57    1   2  130   131    0    1  115         1  1.2     2
# 301         301   57    0   0  130   236    0    2  174         0  0.0     2
# 302         302   38    1   3  138   175    0    1  173         0  0.0     1
#
#           num  thal  y
# ...

# %%
del df['Unnamed: 0']

# %%
x=df['age']
y=df['bp']

covXY= np.cov(x,y)
covXY
# Out:
# array([[ 81.69741875,  45.3286779 ],
#        [ 45.3286779 , 309.75112015]])

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.28494592],
#        [0.28494592, 1.        ]])

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y)

plt.xlabel('age')
plt.ylabel('bp')

plt.show()

# %%
t = df['hr']

np.cov(x,t)
# Out:
# array([[ 81.69741875, -81.42306515],
#        [-81.42306515, 523.26577492]])

# %%
np.corrcoef(x,t)
# Out:
# array([[ 1.        , -0.39380581],
#        [-0.39380581,  1.        ]])

# %%
plt.scatter(x,t)

plt.xlabel('age')
plt.ylabel('hr')

plt.show()

# %%
df.corr()
# Out:
#                age       sex        cp        bp      chol       fbs  \
# age       1.000000 -0.097542  0.077071  0.284946  0.208950  0.118530
# sex      -0.097542  1.000000 -0.048304 -0.064456 -0.199915  0.047862
# cp        0.077071 -0.048304  1.000000 -0.000464  0.011251  0.069390
# bp        0.284946 -0.064456 -0.000464  1.000000  0.130120  0.175340
# chol      0.208950 -0.199915  0.011251  0.130120  1.000000  0.009841
# fbs       0.118530  0.047862  0.069390  0.175340  0.009841  1.000000
# elc       0.113374  0.055217  0.003662  0.119702  0.150779  0.081538
# hr       -0.393806 -0.048663 -0.133860 -0.045351 -0.003432 -0.007854
# exercise  0.091661  0.146201  0.077840  0.064762  0.061310  0.025665
# dep       0.203805  0.102173  0.125724  0.189171  0.046564  0.005747
# slop      0.126718 -0.021937  0.077906 -0.032447  0.055054 -0.070627
# num       0.359489  0.092891  0.066836  0.098707  0.118525  0.143967
# thal      0.062549  0.215039  0.068380  0.058317  0.083298 -0.011209
# ...
